# %%
import yaml
import os, sys, importlib, math
import pandas as pd
import numpy as np
import torch
import time
sys.path.append("../src/tuning/")

# %%
from algo import template, gw
from chessIntegration import chessSpec, tourney
import texel
importlib.reload(template)
importlib.reload(gw)
importlib.reload(texel)
importlib.reload(chessSpec)
# Out:
# __init__.py got invoked at: /mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/algo/__init__.py
# __init__.py got invoked at: /mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/chessIntegration/__init__.py
# <module 'chessIntegration.chessSpec' from '/mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/chessIntegration/chessSpec.py'>

# %%
importlib.reload(texel)
# Out:
# <module 'texel' from '/mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/texel.py'>

# %%
import torch.nn as nn
import sklearn

# %%
a = texel.texelWeights()
a.pushArray(chessSpec.simplePieceCount, texel.countPawn_idx)
a.pushArray([chessSpec.newWeight_0_bis[texel.mobility_idx]], texel.mobility_idx)
a.pushArray([chessSpec.newWeight_0_bis[texel.structureProtection_idx]], texel.structureProtection_idx)
a.pushArray(chessSpec.newWeight_0_bis[texel.isolatedPawnScore_idx:texel.passedPawnScore_idx+1], texel.isolatedPawnScore_idx)
a.pushArray([25], texel.tempoChecksScore_idx)
a.pushArray([10], texel.kingMoveCountScore_idx)
a.pushArray(chessSpec.newWeight_0_bis[texel.safetyKnight_idx:texel.safetyQueen_idx+1], texel.safetyKnight_idx )
a.pushArray([5], texel.kingProximityScore_idx)

a.divide(100)
# Out:
#  [1.0, 3.0, 3.0, 5.0, 9.0] [-0.0] [0.1] [0.2] [0.11] [0.25] [] [0.05]

# %%
testPath = "../out/heuristics/MH/tmp/tmp_1776310745/result_1776382416.yaml"
tmp = gw.GW(popsize=32, maxiter=16)
tmp.loadYaml(testPath)
tmp.setObjective(tourney.objectiveFromConfigFile(testPath))
heur = chessSpec.entryFrom1dArray(tmp.population[0].position, tmp.objective.indexesTemplate)

# %%
heur.weights
# Out:
# [ [0.0] [0.0] [31.0] [2.0] [0.0] [68.0] [90.0] [21.0] [42.0] [0.0] [23.0] [1.0],
#   [11.0] [60.0] [65.0] [1.0] [7.0] [98.0] [0.0] [100.0] [82.0] [7.0] [29.0] [11.0]]

# %%
importlib.reload(texel)
importlib.reload(chessSpec)
# Out:
# <module 'chessIntegration.chessSpec' from '/mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/chessIntegration/chessSpec.py'>

# %%
path = "../logs/test_weights_int_filter_quiesc+endFen_red2_790815.csv"
path = "../logs/test_weights_int_filter_quiesc+endFen_red_prox_2590504.csv"

# %%
path = "../logs/test_weights_int_filter_quiesc+endFen_red_prox_2590504.csv"
model = texel.texelNet(n_weights = texel.total_idx)
n_pos = 100_000
opt: texel.trainingOptions = texel.trainingOptions(
        path = path, 
        pos_per_epoch = n_pos,
        epoch = 4096,
        tuneCfg = texel.tuneConfig(
            tuneCount = True, 
            tuneMobility = True, 
            tuneStructure = False, 
            tunePawnStructure = True, 
            tunePSQT = True, 
            tuneSafety = True,
            tuneTempo = True,
            tuneKingStuff = True), 
        initialWeights=heur.weights, )

texel.training_loop(opt, model = model, freq_pos_change=16, fileSize = 2590504, batch_size=4096)
# Out:
# [DEBUG] training_loop: 2590504 coeffs found
# Epoch: 0: loss = 0.1089523434638977
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 19
#       3 n_pos = 100_000
#       4 opt: texel.trainingOptions = texel.trainingOptions(
#       5         path = path,
#       6         pos_per_epoch = n_pos,
#    (...)
#      16             tuneKingStuff = True),
#      17         initialWeights=heur.weights, )
# ---> 19 texel.training_loop(opt, model = model, freq_pos_change=16, fileSize = 2590504, batch_size=4096)
#
# File /mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/texel.py:138, in training_loop(opt, model, freq_pos_change, fileSize, batch_size)
#     135 if ep % freq_pos_change == 0:
#     136     # change the x and y
#     137     packetIdx = (packetIdx + 1) % packetSize
# --> 138     X, Y = fetchNextXY(
#     139         opt.path, n_pos=opt.pos_per_epoch, nskips=packetIdx * opt.pos_per_epoch
#     140     )
#     141     assert batch_size != 0
#     142     amount_batch: int = math.ceil(len(X) / batch_size)
#
# File /mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/texel.py:64, in fetchNextXY(path, n_pos, nskips)
#      61 def fetchNextXY(
#      62     path: str, n_pos: int, nskips: int
#      63 ) -> tuple[torch.Tensor, torch.Tensor]:
# ---> 64     df = loadTexelWeight(path, n_pos=n_pos, pos_offset=nskips)
#      65     x, y = extractXYFromDF(df)
#      66     del df
#
# File /mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/texel.py:24, in loadTexelWeight(path, n_pos, pos_offset, dtype)
#      20 def loadTexelWeight(
#      21     path: str, n_pos: int, pos_offset: int = 0, dtype: npt.DTypeLike = np.float16
#      22 ) -> pd.DataFrame:
#      23     assert os.path.exists(path)
# ---> 24     ret = pd.read_csv(
#      25         path,
#      26         sep=",",
#      27         dtype=dtype,
#      28         header=0,
#      29         nrows=n_pos,
#      30         skiprows=(1, max(1, pos_offset)),
#      31     )
#      32     assert len(ret) == n_pos, f"expected {n_pos} positions found {len(ret)}"
#      33     return ret
#
# File ~/.pyenv/versions/3.10.13/envs/chess/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/envs/chess/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.10.13/envs/chess/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.pyenv/versions/3.10.13/envs/chess/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:850, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
texel.printTensorWeight(model.W_mg.weight.detach().numpy()[0], True)
texel.printTensorWeight(model.W_eg.weight.detach().numpy()[0], True)
# Out:
# pawnCountScore = 1.0405247211456299
# bishopCountScore = 2.091794967651367
# knightCountScore = 1.9563676118850708
# rookCountScore = 3.5854477882385254
# queenCountScore = 5.114633560180664
# mobilityScore = 0.06032887101173401
# mobilityKingScore = -0.009267530404031277
# structureProtectionScore = -1.1746244247356347e-40
# isolatedPawnScore = 0.0050443499349057674
# stackedPawnScore = -0.09261424839496613
# passedPawnScore = 0.11940133571624756
# tempoChecksScore = -0.04344438388943672
# safetyPawn = 0.0862574502825737
# safetyKnight = 0.03111616149544716
# safetyBishop = 0.01153249479830265
# safetyRook = 0.03775354474782944
# safetyQueen = -0.47834232449531555
# kingProximityScore = -3.412154114812438e-07
# pawnArr:
# 0, 0, 0, 0, 0, 0, 0, 0,
# 60, 61, 54, 28, 47, 47, 49, 69,
# 40, 38, 19, 19, 23, 25, 34, 39,
# -7, -3, -10, -14, -9, -10, -5, -11,
# -21, -13, -22, -22, -21, -21, -17, -20,
# -24, -20, -18, -15, -16, -17, -20, -27,
# -22, -16, -18, -16, -18, -16, -21, -28,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# 7, 3, 9, 9, 10, 17, 0, -6,
# 12, -1, 11, 9, 9, -1, 4, 10,
# 7, 8, 1, 12, 2, 9, 4, 3,
# 9, 11, 6, -2, 7, 4, 18, 5,
# -10, 11, 10, 0, 0, 1, 5, 6,
# 1, -7, 1, 3, 10, 1, 4, -5,
# 0, -4, -14, 4, -2, 0, 0, -16,
# -6, -7, -2, 6, -4, 0, -1, 0,
# knightArr:
# -9, -2, 6, -2, 8, 16, 8, -4,
# 5, 1, 3, 10, 18, 10, -3, -4,
# -6, 1, 5, 10, 5, 13, -6, 1,
# 9, 4, 18, 20, 30, 12, 21, 3,
# 5, 1, 5, 7, 12, 11, 10, 4,
# 3, -9, -2, 9, 5, 5, -4, -5,
# -12, -5, 7, 1, -1, -5, 10, -7,
# -5, -14, -3, -3, -6, 9, -29, -8,
# rookArr:
# 16, 16, 14, 15, 16, 16, 17, 23,
# 13, 13, 13, 28, 16, 12, 10, 12,
# 13, 3, 10, 9, 11, 13, 5, 4,
# 4, 12, 7, 17, 9, 8, 10, 7,
# 5, 10, 4, 7, 10, 3, 0, 6,
# -11, -1, 5, 3, 0, 2, 0, -6,
# 1, -18, -3, -4, 0, -2, -11, -14,
# -3, -6, -2, -4, -4, -3, -10, -4,
# queenArr:
# 9, 29, 20, 13, 8, 22, 22, 9,
# 16, 5, 8, 7, 9, 14, 15, 13,
# 15, 7, 11, 8, 18, 11, 10, 15,
# 2, 5, 12, 12, 17, 21, 20, 4,
# 14, 17, 11, 6, 11, 10, 15, 8,
# -7, 9, -3, 9, 0, 0, -3, -1,
# -5, -3, 11, -2, 13, 2, 8, -5,
# -4, -5, 4, 2, -13, -9, -3, 0,
# kingArr:
# -6, 5, 3, -8, -5, 6, 3, 2,
# 4, 8, 7, 4, 0, -3, 8, -17,
# 6, 24, 15, 7, -1, 16, 16, 11,
# 0, 3, 8, 11, 17, 11, 6, 2,
# -5, 2, 4, 8, 10, 2, 2, -3,
# 4, -3, 1, 2, 0, 0, -2, -6,
# -6, -8, -6, -10, -10, -8, -10, -9,
# -19, -7, 0, -28, -19, -3, -9, -28,
# pawnCountScore = 0.24915678799152374
# bishopCountScore = 0.5763007402420044
# knightCountScore = 0.5195116400718689
# rookCountScore = 0.5060927271842957
# queenCountScore = 2.5569229125976562
# mobilityScore = 0.0015153344720602036
# mobilityKingScore = 0.03470754250884056
# structureProtectionScore = -1.0970765677198993e-40
# isolatedPawnScore = -0.11696653068065643
# stackedPawnScore = -0.013931810855865479
# passedPawnScore = -0.16424532234668732
# tempoChecksScore = 0.04062606394290924
# safetyPawn = -0.061318352818489075
# safetyKnight = -0.09856051951646805
# safetyBishop = -0.18992772698402405
# safetyRook = -0.24497249722480774
# safetyQueen = -0.10659109055995941
# kingProximityScore = 6.859535855996413e-11
# pawnArr:
# 0, 0, 0, 0, 0, 0, 0, 0,
# 15, 24, 27, 22, 20, 17, 23, 37,
# -7, -4, 5, 10, 16, 17, 5, 5,
# 2, -6, -9, -1, 2, 2, 0, -1,
# -6, -10, -10, -2, -10, -7, -1, -9,
# -2, -9, -4, -7, -14, -13, -6, -7,
# -3, -13, -2, -21, -19, -4, -7, -6,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# 1, 3, -2, -2, 4, 0, 0, -1,
# 1, 7, 0, 2, 9, -1, 4, -10,
# 10, 5, 3, -13, 9, 3, 7, -8,
# 7, -7, 4, 11, 0, -3, 0, -1,
# -6, 3, 0, 17, 20, -7, -9, -1,
# 5, 1, 4, 7, -7, 7, 6, 4,
# -2, 0, 1, -2, -2, -1, 11, -15,
# 2, -8, -6, -2, -22, -4, 10, 9,
# knightArr:
# -10, -1, 3, 1, 0, -2, 3, -4,
# 4, -1, 5, 8, 0, 1, -1, 0,
# -1, 1, -8, 16, 23, 7, 3, 0,
# 15, -5, 19, 9, -2, 9, -4, 4,
# -4, 0, 9, 4, 5, -10, 5, 1,
# -6, -6, 4, -1, 1, 0, 0, -4,
# -3, -6, -4, 2, -5, -8, 3, -10,
# -2, 0, 7, -11, -4, -9, 3, 3,
# rookArr:
# 5, 2, 0, 0, 8, 7, 2, 6,
# 13, 26, 4, 3, 6, 4, 7, 10,
# 3, 16, 8, 6, 18, 9, 3, 0,
# -15, -8, 0, 0, 12, 4, 2, 6,
# -5, 3, 12, -3, -1, 8, 2, -13,
# -6, -1, -2, -7, -14, -10, -8, -1,
# -25, 0, -1, -24, -6, 1, 0, -9,
# -9, -3, 0, 2, -2, 0, 5, -1,
# queenArr:
# 6, 14, 14, -2, 4, 16, 8, 16,
# 8, 4, 11, 1, -9, -5, -7, 11,
# -3, 15, 15, -16, -7, 10, 3, 6,
# 22, 14, 10, -2, 1, -1, 15, 19,
# -2, 12, -3, 12, -1, 1, 9, -1,
# 0, -4, 13, 5, 3, 0, 9, 9,
# -17, 1, 9, 8, 2, 9, -6, -15,
# 3, -13, -5, 11, 6, 0, -4, 4,
# kingArr:
# 0, 0, 1, 0, 0, 3, 1, -1,
# 2, 0, 2, 1, 2, 3, 1, -4,
# 0, 9, 5, 3, 1, 6, 7, 1,
# -3, 3, 8, -1, 3, 0, 5, 0,
# 3, -3, 8, 0, 13, 14, 5, 10,
# -20, -11, -7, 5, 2, -13, -13, -10,
# 6, -14, -22, -5, -22, 0, -5, 17,
# 7, 11, -16, -1, -12, -9, 7, 8,

# %%
texel.saveModelWeightToFile(path = f"test_{int(time.time())}.winfo",  model = model)

# %%
texel.saveModelWeightToFile(path = f"test_{int(time.time())}.winfo",  model = model, convertToCP=True)

# %%
path = "../logs/test_weights_int_filter_quiesc+endFen_red_4848838.csv"
model = texel.texelNet(n_weights = texel.total_idx)
n_pos = 100_000
opt: texel.trainingOptions = texel.trainingOptions(
        path = path, 
        pos_per_epoch = n_pos,
        epoch = 512,
        tuneCfg = texel.tuneConfig(
            tuneCount = True, 
            tuneMobility = True, 
            tuneStructure = True, 
# -5, -1, -6, -21, -17, -13, -5, -12,
# -19, -17, -23, -26, -22, -24, -19, -16,
# -27, -22, -17, -12, -20, -13, -14, -24,
# -17, -17, -9, -14, -13, -9, -12, -23,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# 11, 6, -4, 1, -1, 1, 2, 0,
# 11, 6, 15, 7, 5, 8, 4, 0,
# 8, 12, 13, 17, 9, 19, 7, 5,
# 3, 6, 20, 14, 18, 18, 21, -1,
# -16, 8, 9, 9, 13, 5, -3, -11,
# -12, 2, 11, 12, 12, 11, 2, 2,
# -2, -9, -5, -2, 4, -27, 1, -11,
# 4, -23, -10, -7, -15, -10, -12, -2,
# knightArr:
# -8, -4, 1, -8, 10, 9, 5, -7,
# -7, -1, 8, 18, 22, 17, 1, -8,
# -4, 6, 14, 26, 23, 21, -1, 3,
# -9, 17, 25, 33, 31, 26, 15, 10,
# 1, 3, 20, 26, 41, 12, 6, 0,
# -20, -13, -4, 10, 18, -5, 8, -19,
# -11, -3, -2, 0, -2, -10, -4, -7,
# -11, -24, -12, -19, -15, -15, -24, -10,
# rookArr:
# 21, 15, 23, 27, 17, 21, 18, 32,
# 15, 22, 18, 14, 25, 20, 18, 13,
# 10, 7, 21, 17, 18, 15, 1, 6,
# 4, 0, 2, 16, 10, 11, 10, 4,
# 2, 13, 8, 1, 19, 0, -3, -8,
# -16, -10, 6, 0, -8, -7, 1, -1,
# -7, -24, -13, -13, -4, 0, -19, -4,
# -11, 6, -9, 0, -6, -1, -3, -11,
# queenArr:
# -7, 22, 22, 28, 13, 17, 25, 6,
# 16, 10, 26, 24, 19, 9, 22, 16,
# 19, 22, 14, 19, 24, 23, 6, 22,
# 9, 0, 14, 30, 22, 27, 26, -2,
# 9, -5, 12, 42, 28, 24, 20, 3,
# -4, -12, 0, 6, 6, 10, -8, 8,
# -5, -5, -10, -21, -13, -25, -14, 2,
# -5, -11, -3, -37, -36, -14, 0, -6,
# kingArr:
# 0, 7, 0, -4, -7, 1, -2, 2,
# 0, 15, 2, -2, -8, 12, 20, -1,
# -5, 8, 16, 16, 15, 23, 30, 7,
# 3, 15, 11, 26, 19, 21, 13, 8,
# -3, 10, 10, 18, 13, 14, 11, -3,
# -11, -4, 6, 5, 7, 0, -5, -19,
# -24, -14, 0, -5, -10, 0, -15, -15,
# -43, -18, -16, -34, -34, -18, -18, -33,
# pawnSafety: 9.389657078087101e-38, bishopSafety: 6.110403992642295e-39,     knightSafety: -1.5712199161088444e-39, rookSafety: -2.6147234422391416e-39, queenSafety: 5.4248467449406643e-39

# %%
texel.printTensorWeight(model.W_eg.weight.detach().numpy()[0], True)
# Out:
# pawnCount: 0.294914573431015, bishopCount: 0.6965816020965576, knightCount: 0.8606593608856201, rookCount: 1.0462030172348022, queenCount: 3.048074960708618
# moveCount: -0.005382465198636055, structureProtection: 0.020338863134384155
# isolatedScore: -0.09834253042936325, stackedScore: -0.022000053897500038, passedScore: -0.10072322189807892
# pawnArr:
# 0, 0, 0, 0, 0, 0, 0, 0,
# 30, 24, 26, 30, 36, 29, 27, 46,
# -27, 20, 27, 12, 37, 25, 0, -1,
# -12, -4, 6, 12, 8, -4, -2, -10,
# -13, -12, -12, -8, -5, -11, -5, -17,
# -13, -14, -15, -10, -9, -19, -15, -14,
# -13, -8, -10, -22, -16, -12, -17, -19,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# -4, 1, 8, 0, 2, -1, -4, 7,
# 2, 7, -2, 10, 0, 6, 6, -1,
# -1, 3, 28, 3, 17, 1, 13, 12,
# 5, 6, -8, 20, 18, 6, -2, 8,
# -6, -6, -4, 19, 5, 4, -3, -1,
# 2, -3, 3, 4, -2, -2, -2, 7,
# -4, 5, -4, -6, -4, 4, 5, -5,
# -11, -15, -15, -25, 0, -11, -8, 5,
# knightArr:
# -7, -2, -1, 0, 6, 0, 1, -6,
# 8, 8, -2, 11, 6, 17, -31, 10,
# -2, -2, 29, 27, 25, 43, 19, -3,
# 14, 11, 20, 20, 23, 23, 2, 14,
# 0, -6, 10, 7, -2, 9, 4, -11,
# -13, 0, -2, 0, 2, -1, -10, -12,
# -5, -26, -19, -4, -3, -1, 0, -10,
# -17, -11, -23, -6, -16, -15, -5, -18,
# rookArr:
# 23, 17, 11, 4, 1, -1, 2, 16,
# 21, 12, 15, 29, 9, 25, 17, 23,
# 15, 25, 29, 15, 26, 23, 34, 7,
# 12, -11, 10, 10, 16, 8, -2, 9,
# 5, -2, -7, 0, -11, -4, 1, -5,
# -18, -14, -12, -22, -8, -9, -10, -16,
# -36, -2, -21, -9, -20, -19, -16, -21,
# -16, -9, -10, -9, -5, -7, -5, -12,
# queenArr:
# -6, 15, 12, 26, 6, 12, 15, 3,
# 6, 8, 19, 24, 15, 14, -2, 11,
# 10, 31, 23, 20, -3, 12, 5, 15,
# 13, 7, 18, 4, 11, 24, 10, 15,
# -2, 10, 11, -8, 3, 3, 12, -13,
# -2, 0, -8, -4, 2, 0, -1, -4,
# -14, 1, 0, 1, -5, 4, -7, -9,
# -9, -28, -10, -1, 0, -5, -6, -8,
# kingArr:
# 0, 2, -1, -1, 0, 1, 0, 0,
# 1, 1, 3, -1, -3, 3, 4, 0,
# -1, 0, 7, 2, 7, 3, 6, 0,
# -1, 6, 1, 8, 2, 5, 4, 5,
# -2, -3, 8, -1, 12, 9, 8, 3,
# -4, -15, -5, -6, 0, 10, 8, 0,
# 8, 5, -22, -23, -23, -19, 5, 5,
# 8, 8, -10, -5, -14, -11, 9, 0,
# pawnSafety: 1.1473145189644083e-39, bishopSafety: 1.922110656769636e-39,     knightSafety: -6.65600515492102e-39, rookSafety: 3.836952778404819e-39, queenSafety: 3.5268529952614443e-38

# %%
path = "../logs/test_weights_int_all.csv"
#def training_loop(path: str, pos_per_epoch: int, epoch: int, model: nn.Module, freq_pos_change: int = 4):
model = texel.texelNet(n_weights = texel.total_idx)
n_pos = 200_000
opt: texel.trainingOptions = texel.trainingOptions(
        path = path, 
        pos_per_epoch = n_pos,
        epoch = 256,
        tuneCfg = texel.tuneConfig(
            tuneCount = False, 
            tuneMobility = False, 
            tuneStructure = False, 
            tunePawnStructure = False, 
            tunePSQT = True, 
            tuneSafety = False), 
        initialWeights=a)

texel.training_loop(opt, model = model, freq_pos_change=4, fileSize = 9999740, batch_size=256)
# Out:
# [DEBUG] training_loop: 9999740 coeffs found
# Epoch: 0: loss = 0.19766166806221008
# Epoch: 10: loss = 0.13114912807941437
# Epoch: 20: loss = 0.11019118875265121
# Epoch: 30: loss = 0.15427947044372559
# Epoch: 40: loss = 0.1501206010580063
# Epoch: 50: loss = 0.13233329355716705
# Epoch: 60: loss = 0.14394530653953552
# Epoch: 70: loss = 0.13667622208595276
# Epoch: 80: loss = 0.1352207213640213
# Epoch: 90: loss = 0.13730883598327637
# Epoch: 100: loss = 0.13712677359580994
# Epoch: 110: loss = 0.1369856297969818
# Epoch: 120: loss = 0.1370965987443924
# Epoch: 130: loss = 0.13715527951717377
# Epoch: 140: loss = 0.13722172379493713
# Epoch: 150: loss = 0.13727226853370667
# Epoch: 160: loss = 0.13727344572544098
# Epoch: 170: loss = 0.13727439939975739
# Epoch: 180: loss = 0.1373021900653839
# Epoch: 190: loss = 0.1373085379600525
# Epoch: 200: loss = 0.137172669172287
# Epoch: 210: loss = 0.13732248544692993
# Epoch: 220: loss = 0.13732706010341644
# Epoch: 230: loss = 0.13733378052711487
# Epoch: 240: loss = 0.1373324692249298
# Epoch: 250: loss = 0.13733837008476257

# %%
texel.saveModelWeightToFile(path = f"test_{int(time.time())}.winfo",  model = model)

# %%
path = "../logs/test_weights_int_all.csv"
#def training_loop(path: str, pos_per_epoch: int, epoch: int, model: nn.Module, freq_pos_change: int = 4):
model = texel.texelNet(n_weights = 399)
n_pos = 200_000
texel.training_loop(path = path, pos_per_epoch=n_pos, epoch=256, model = model, freq_pos_change=4, fileSize = 9999740, batch_size=128)
# Out:
# [DEBUG] training_loop: 9999740 coeffs found
# Epoch: 0: loss = 0.13491231203079224
# Epoch: 10: loss = 0.12107735127210617
# Epoch: 20: loss = 0.11465266346931458
# Epoch: 30: loss = 0.11285767704248428
# Epoch: 40: loss = 0.11111404746770859
# Epoch: 50: loss = 0.1113070547580719
# Epoch: 60: loss = 0.11244212836027145
# Epoch: 70: loss = 0.11246014386415482
# Epoch: 80: loss = 0.1115327849984169
# Epoch: 90: loss = 0.11138298362493515
# Epoch: 100: loss = 0.11126890033483505
# Epoch: 110: loss = 0.11097348481416702
# Epoch: 120: loss = 0.11080969125032425
# Epoch: 130: loss = 0.11058463156223297
# Epoch: 140: loss = 0.11036299169063568
# Epoch: 150: loss = 0.11011683940887451
# Epoch: 160: loss = 0.10987650603055954
# Epoch: 170: loss = 0.10963510721921921
# Epoch: 180: loss = 0.10940046608448029
# Epoch: 190: loss = 0.10917310416698456
# Epoch: 200: loss = 0.10925225913524628
# Epoch: 210: loss = 0.10874718427658081
# Epoch: 220: loss = 0.10854499042034149
# Epoch: 230: loss = 0.1083555519580841
# Epoch: 240: loss = 0.10817501693964005
# Epoch: 250: loss = 0.10800454765558243

# %%
importlib.reload(texel)
# Out:
# <module 'texel' from '/mnt/c/Users/iTreek/Documents/Formation/Zig_adventures/chess/test/../src/tuning/texel.py'>

# %%
texel.printTensorWeight(model.W_eg.weight.detach().numpy()[0], True)
# Out:
# pawnCount: 0.23529860377311707, bishopCount: 0.7967561483383179, knightCount: 0.7441341876983643, rookCount: 1.1927363872528076, queenCount: 2.4444518089294434
# moveCount: -0.0099063441157341, structureProtection: 0.021880371496081352
# isolatedScore: -0.09546655416488647, stackedScore: -0.026617757976055145, passedScore: -0.10850785672664642
# pawnArr:
# 0, 0, 0, 0, 0, 0, 0, 0,
# 110, 85, 86, 120, 105, 79, 83, 113,
# -24, 41, 47, 33, 52, 36, 12, 0,
# -6, 4, 10, 20, 13, 8, 3, -5,
# -4, -2, -6, 1, 1, -4, -1, -8,
# -5, -8, -8, -1, -3, -12, -8, -7,
# -7, -4, -7, -8, -10, -5, -8, -10,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# 0, 88, 32, 27, 70, 50, 15, 66,
# 37, 50, 40, 63, 37, 59, 33, 41,
# 42, 36, 79, 52, 60, 50, 51, 54,
# 27, 37, 34, 58, 47, 42, 33, 46,
# 31, 26, 29, 45, 42, 37, 33, 39,
# 38, 30, 30, 38, 28, 31, 31, 38,
# 25, 35, 31, 24, 32, 30, 39, 36,
# 22, 33, 20, 15, 23, 26, 36, 46,
# knightArr:
# -50, 9, 3, 34, 80, -45, 6, -34,
# 31, 6, 49, 59, 13, 34, -14, 20,
# 35, 30, 59, 59, 57, 60, 51, 18,
# 32, 27, 36, 36, 38, 40, 22, 32,
# 11, 7, 20, 25, 18, 25, 18, 6,
# -4, 14, 14, 12, 19, 14, 9, 5,
# 22, -9, 0, 10, 10, 5, 7, 0,
# -59, 4, -9, -1, -4, 0, 11, -44,
# rookArr:
# 70, 105, 61, 52, 55, 65, 58, 88,
# 68, 79, 78, 90, 57, 87, 62, 87,
# 51, 77, 70, 82, 67, 78, 85, 58,
# 47, 31, 60, 55, 67, 55, 40, 46,
# 34, 32, 19, 31, 20, 34, 37, 22,
# 22, 37, 18, 13, 30, 15, 31, 31,
# -18, 37, 22, 26, 21, 24, 19, 6,
# 27, 33, 27, 31, 36, 31, 33, 30,
# queenArr:
# 52, 105, 116, 135, 130, 118, 102, 84,
# 72, 71, 77, 77, 82, 100, 55, 86,
# 79, 105, 84, 79, 69, 93, 81, 84,
# 90, 87, 83, 67, 76, 96, 71, 84,
# 70, 79, 74, 61, 75, 76, 77, 58,
# 53, 75, 65, 67, 69, 67, 74, 61,
# 60, 68, 76, 71, 70, 83, 71, 60,
# 59, 52, 64, 72, 73, 72, 65, 60,
# kingArr:
# -67, -61, -22, 191, -105, -203, 142, -61,
# -51, 32, 108, 9, -39, 41, 75, -176,
# -78, 79, 18, 14, -8, 69, 54, -60,
# -61, -30, 25, 0, 4, 21, 37, 11,
# -32, -24, 3, -34, 57, 41, 13, 26,
# -13, -35, -27, -28, -20, 1, 1, 0,
# 3, -5, -31, -30, -39, -32, 5, 8,
# 6, 3, -19, -12, -18, -11, 7, 0,
# pawnSafety: 9.970099412726086e-09, bishopSafety: 2.712338798005476e-08,           knightSafety: -1.9876386758710396e-08, rookSafety: 4.79965365229873e-08, queenSafety: -3.4746140187280616e-08

# %%
texel.printTensorWeight(model.W_mg.weight.detach().numpy()[0], True)
# Out:
# pawnCount: 0.4611072242259979, bishopCount: 0.7456916570663452, knightCount: 0.9864108562469482, rookCount: 1.5362528562545776, queenCount: 2.351408004760742
# moveCount: 0.007389955222606659, structureProtection: 0.02819824405014515
# isolatedScore: 0.015992512926459312, stackedScore: -0.08590032905340195, passedScore: 0.11567986011505127
# pawnArr:
# 0, 0, 0, 0, 0, 0, 0, 0,
# 83, 82, 78, 44, 79, 86, 84, 94,
# 77, 59, 46, 54, 51, 47, 66, 69,
# 29, 38, 28, 14, 20, 22, 29, 29,
# 19, 17, 13, 14, 16, 13, 19, 18,
# 14, 14, 20, 24, 16, 18, 19, 11,
# 24, 19, 29, 19, 16, 27, 25, 16,
# 0, 0, 0, 0, 0, 0, 0, 0,
# bishopArr:
# 80, 67, 71, 74, 58, 70, 69, 43,
# 78, 68, 85, 71, 80, 61, 66, 63,
# 74, 81, 62, 83, 72, 83, 75, 65,
# 68, 74, 79, 68, 82, 74, 90, 60,
# 49, 72, 77, 73, 76, 73, 67, 62,
# 46, 63, 73, 71, 78, 71, 72, 61,
# 72, 57, 47, 59, 59, 42, 65, 27,
# 47, 12, 51, 49, 48, 44, 61, 51,
# knightArr:
# 36, 66, 64, 43, 74, 87, 84, 62,
# 37, 51, 57, 68, 88, 68, 63, 52,
# 41, 69, 67, 72, 66, 76, 49, 55,
# 39, 63, 77, 79, 86, 80, 67, 60,
# 54, 67, 75, 75, 85, 71, 62, 54,
# 11, 34, 43, 64, 66, 42, 52, 24,
# -1, 59, 37, 48, 46, 41, 46, 25,
# 10, 2, 36, 39, 34, 34, 6, 17,
# rookArr:
# 123, 109, 126, 133, 124, 123, 126, 121,
# 114, 114, 117, 116, 127, 111, 118, 114,
# 118, 107, 121, 110, 113, 117, 105, 110,
# 111, 115, 107, 123, 112, 111, 118, 112,
# 107, 122, 115, 111, 126, 101, 106, 106,
# 85, 84, 99, 105, 94, 100, 111, 96,
# 104, 70, 89, 90, 91, 97, 86, 87,
# 91, 106, 101, 99, 95, 98, 94, 87,
# queenArr:
# 176, 177, 181, 168, 151, 172, 181, 166,
# 186, 183, 196, 193, 183, 175, 194, 175,
# 190, 158, 187, 195, 197, 181, 177, 187,
# 149, 141, 180, 194, 190, 179, 198, 157,
# 152, 157, 169, 189, 172, 174, 174, 161,
# 153, 129, 148, 154, 155, 162, 124, 178,
# 142, 133, 125, 127, 137, 101, 118, 132,
# 106, 95, 110, 80, 94, 91, 119, 110,
# kingArr:
# -16, 49, 19, -60, 5, 18, -12, 34,
# 8, 21, 0, 10, -1, 16, 32, -8,
# 19, 8, 29, 14, 25, 21, 30, 24,
# 27, 22, 15, 30, 27, 23, 11, 3,
# 6, 16, 11, 25, 12, 8, 7, -12,
# -6, 6, 12, 15, 13, 2, -1, -21,
# -15, -6, 5, 1, 1, 4, -13, -12,
# -44, -11, -9, -27, -33, -16, -15, -34,
# 0.9053999781608582, 0.8741999864578247, 0.8349999785423279, 0.6762999892234802, 0.7662000060081482, 0.9657999873161316, 0.7111999988555908, 0.8496000170707703,
# 0.7005000114440918, 0.792900025844574, 0.7426999807357788, 0.6101999878883362, 0.7573000192642212, 0.765500009059906, 0.770799994468689, 0.5878999829292297,
# 0.5343999862670898, 0.7520999908447266, 0.6588000059127808, 0.6722999811172485, 0.6952999830245972, 0.6722000241279602, 0.7494999766349792, 0.6179999709129333,
# 0.6039000153541565, 0.6899999976158142, 0.7642999887466431, 0.7178999781608582, 0.7031000256538391, 0.8317999839782715, 0.7149999737739563, 0.6014000177383423,
# 0.5957000255584717, 0.5296000242233276, 0.6488999724388123, 0.7245000004768372, 0.7339000105857849, 0.7236999869346619, 0.6517999768257141, 0.6018999814987183,
# kingArr:
# -0.6771000027656555, -0.6187000274658203, -0.225600004196167, 1.916700005531311, -1.0520999431610107, -2.0318000316619873, 1.4247000217437744, -0.6152999997138977,
# -0.5134000182151794, 0.32850000262260437, 1.0843000411987305, 0.09109999984502792, -0.39469999074935913, 0.41339999437332153, 0.754800021648407, -1.76010000705719,
# -0.7886999845504761, 0.7954999804496765, 0.1882999986410141, 0.14560000598430634, -0.08079999685287476, 0.6977999806404114, 0.5443000197410583, -0.6083999872207642,
# -0.6150000095367432, -0.30660000443458557, 0.2583000063896179, -0.006099999882280827, 0.04639999940991402, 0.21940000355243683, 0.3749000132083893, 0.11699999868869781,
# -0.3215000033378601, -0.24860000610351562, 0.037300001829862595, -0.3474000096321106, 0.5752000212669373, 0.4108000099658966, 0.13459999859333038, 0.2653999924659729,
# -0.13339999318122864, -0.3573000133037567, -0.2800000011920929, -0.2815999984741211, -0.20090000331401825, 0.012199999764561653, 0.014800000004470348, 0.0066999997943639755,
# 0.03779999911785126, -0.05490000173449516, -0.3156000077724457, -0.3050000071525574, -0.3986000120639801, -0.3215999901294708, 0.05270000174641609, 0.08030000329017639,
# 0.06930000334978104, 0.039400000125169754, -0.19820000231266022, -0.125, -0.18219999969005585, -0.11540000140666962, 0.07419999688863754, 0.005200000014156103,
# pawnSafety: 9.970099412726086e-09, bishopSafety: 2.712338798005476e-08,           knightSafety: -1.9876386758710396e-08, rookSafety: 4.79965365229873e-08, queenSafety: -3.4746140187280616e-08

# %%
path = "../logs/test_weights.csv"
df = texel.loadTexelWeight(path, n_pos = 10_000, dtype = np.float16)
x, y = texel.extractXYFromDF(df)
#x[:, -2:]*=100

# %%
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.2, random_state=42)
n_weights = x.shape[1] - 2 # -2 for the 2 factors added
del x, y

# %%
torch_x_train = torch.from_numpy(x_train).float()
torch_y_train = torch.from_numpy(y_train.reshape(-1, 1)).float()

torch_x_test = torch.from_numpy(x_test).float()
torch_y_test = torch.from_numpy(y_test.reshape(-1, 1)).float()
best_weights = [None, None]
best_loss_test = float("inf")
best_epoch = 0

# %%
batch_size = 32
amount_batch = math.ceil(len(torch_x_train) / batch_size)
print(amount_batch)
# Out:
# 250

# %%
torch_x_train.dtype
# Out:
# torch.float32

# %%
batch_size = 128
amount_batch = math.ceil(len(torch_x_train) / batch_size)
print(amount_batch)
model = texel.texelNet(n_weights = n_weights)
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001, weight_decay=0.0001)
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=128, gamma=0.80)
for epoch in range(8192):
    optimizer.zero_grad()  # Zero the gradients
    for batch in range(amount_batch):
        outputs = model(torch_x_train[batch*batch_size:(batch + 1)*batch_size])
        loss = criterion(outputs, torch_y_train[batch*batch_size:(batch + 1)*batch_size])
        loss.backward()  # Backward pass
    optimizer.step()  # Update the parameters

    # scheduler.step()
    outp_test = model(torch_x_test)
    loss_test = criterion(outp_test, torch_y_test)
    if (loss_test.item() < best_loss_test):
        best_weights[0] = np.copy(model.W_mg.weight.detach().numpy())
        best_weights[1] = np.copy(model.W_eg.weight.detach().numpy())
        best_loss_test = loss_test.item()
        best_epoch = epoch
    if (epoch % 10 == 0):
        print(f"Epoch: {epoch}: loss = {loss.item()}, loss_test: {loss_test.item()}")
# Out:
# 63

# %%
next(model.named_parameters())
# Out:
# ('W_mg.weight',
#  Parameter containing:
#  tensor([[ 4.4602e-02,  2.3737e-02, -3.7719e-02, -3.9938e-02,  2.6681e-02,
#            3.5593e-02,  3.5206e-02, -1.6445e-02,  4.0369e-02, -4.7975e-02,
#           -9.8749e-03, -3.6465e-02, -3.2140e-02,  2.3025e-02, -3.9364e-02,
#            1.6537e-02, -3.1166e-02, -2.1093e-02,  4.1625e-02, -6.1693e-03,
#           -1.7567e-02,  4.2547e-02, -4.9955e-02, -4.7627e-02,  6.0621e-03,
#            2.9100e-02,  4.1466e-02, -7.8062e-03, -6.5795e-03,  1.3830e-02,
#           -4.6483e-02,  3.0426e-02,  3.6137e-02,  4.2065e-02,  2.2531e-02,
#           -2.8749e-02,  1.1850e-02,  2.2889e-02, -3.4920e-02, -4.6444e-02,
#           -4.9028e-02, -4.0071e-02, -2.6940e-02,  3.5428e-02,  1.6071e-02,
#            2.3322e-03, -2.6704e-02,  3.0531e-02, -1.6525e-02, -4.5298e-02,
#           -2.2987e-02,  4.8558e-02,  3.8496e-03,  2.5782e-02, -2.8538e-02,
#            4.4194e-02, -1.7952e-02,  9.1897e-03, -2.2116e-02,  3.4380e-02,
#           -1.5721e-02,  3.3597e-02,  1.9727e-02,  4.5400e-02,  4.8785e-02,
#           -3.0321e-02,  1.9227e-02,  6.5780e-03, -3.5009e-02,  4.2847e-03,
#           -1.8309e-02, -2.4821e-02, -1.8572e-02, -4.8552e-02, -1.7398e-02,
#           -1.6664e-02, -2.7270e-02,  3.0769e-02,  3.3601e-02, -3.4984e-02,
#           -1.1318e-02, -2.2412e-02, -9.8447e-03, -1.2825e-02, -1.0956e-02,
#           -4.7947e-02,  3.1574e-02, -2.5851e-02, -1.3407e-02,  3.6149e-02,
#            1.1615e-02,  2.7609e-02,  4.3627e-02, -3.5720e-02, -5.7525e-03,
#            7.3028e-03,  4.4510e-02, -4.4495e-02,  1.6897e-03,  4.4898e-02,
#            6.0082e-03, -7.4503e-03, -4.8085e-02,  1.4521e-02,  3.1945e-02,
#           -4.7657e-02, -4.7517e-02, -1.0417e-02, -4.9189e-02, -5.0053e-02,
#            2.2279e-02, -4.9955e-02, -4.4317e-02,  1.0397e-03, -6.7906e-03,
#           -4.4589e-02,  3.6322e-02, -4.4440e-03,  3.2508e-03,  2.6262e-03,
#           -3.4539e-02,  4.1053e-03, -3.3844e-02, -2.8243e-02,  1.2298e-03,
#           -3.2234e-02,  3.4395e-03,  4.4504e-02, -1.0139e-02,  3.9210e-02,
#           -3.6793e-02,  7.1574e-03, -4.7984e-02,  3.6124e-02,  1.2491e-02,
#           -2.5588e-02,  8.1063e-03,  1.9205e-02, -3.2067e-02,  2.9388e-02,
#           -4.0616e-02,  4.8092e-02,  1.6750e-02,  2.8900e-02,  4.0959e-02,
#            4.3256e-02, -1.5015e-02, -2.4056e-02, -4.0985e-02,  6.3736e-03,
#           -4.3837e-02, -2.5342e-02, -2.3594e-02,  4.4530e-02,  2.0750e-03,
#            3.1467e-02,  1.1367e-02, -3.2065e-02,  3.8829e-02,  4.8918e-02,
#           -2.5754e-02,  2.8707e-02, -1.3604e-02,  3.8593e-02,  2.3268e-03,
#           -3.3140e-03, -4.7719e-02, -2.7447e-02, -1.0908e-02, -3.4132e-03,
#           -4.3182e-02,  3.2916e-03, -4.4283e-02, -5.0087e-02,  2.2855e-03,
#           -4.8407e-02,  4.6135e-02, -2.0655e-02,  1.4349e-03, -4.2564e-02,
#           -1.5887e-02, -1.5934e-02, -5.7009e-03,  9.2819e-03,  3.5140e-02,
#            3.0975e-02,  3.8331e-02, -4.1484e-02,  8.3608e-03, -4.2356e-02,
#           -2.3250e-02, -1.4588e-02, -4.8610e-03, -2.1321e-02,  7.7591e-03,
#           -4.6028e-02, -3.1385e-02, -6.6429e-04,  3.1222e-02, -2.5750e-02,
#            1.7608e-02,  1.1054e-03,  1.6283e-02, -2.6277e-03, -9.2852e-03,
#            3.7444e-02, -2.8152e-02,  2.7516e-05, -3.2668e-02,  1.3362e-03,
#           -1.9987e-02,  6.8435e-03,  1.9348e-02,  3.4663e-02,  1.6878e-02,
#            4.5490e-02,  9.3768e-03, -4.0957e-02, -7.4899e-03, -8.3745e-03,
#            4.6422e-02,  5.1506e-03,  4.1572e-02, -8.8406e-03, -2.2222e-02,
#            2.8320e-02,  3.3819e-02, -3.7078e-02, -1.0364e-02,  3.6411e-02,
#            4.0264e-02, -1.3736e-02]], requires_grad=True))

# %%
params = model.named_parameters()
mg = next(params)

# %%
(torch.mul(mg[1].grad, mg[1].grad)).shape
# Out:
# torch.Size([1, 397])

# %%
type(mg[1][0])
# Out:
# torch.Tensor

# %%
totalPhase = 32
def computeMerge(score: int, phase: int):
    phase = int((phase * 256 + int(totalPhase/2)) / totalPhase)
    return int(((score * (256 - phase)) + score * phase) / 256)

# %%
computeMerge(16, 0)
# Out:
# 16

# %%
import matplotlib.pyplot as plt

# %%
x = np.arange(0, 32)
scores = [0, 100, -100, -500, 500, 1000] 
fig, ax = plt.subplots()
for score in scores:   
    y = [computeMerge(score, e) for e in x]
    ax.scatter(x, y)
